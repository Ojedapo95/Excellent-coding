# %% [markdown]
# <a href="https://colab.research.google.com/github/Ojedapo95/Excellent-coding/blob/main/My_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Student Performance Analyzer
Name = "Ojedapo Rodah Opeyemi"
Age = 31
Department = "Art education"

Mathematics = 85
Python = 87
Statistics = 92
Total_score = Mathematics + Python + Statistics
Average_score = Total_score / 3
Highest_score = Mathematics

if Python > Highest_score:
    Highest_score = Python

if Statistics > Highest_score:
    Highest_score = Statistics

Lowest_score = Mathematics

if Python < Lowest_score:
    Lowest_score = Python

if Statistics < Lowest_score:
    Lowest_score = Statistics

Pass = Average_score >= 50

print("Student Performance Analyzer")
print("Name:", Name)
print("Age:", Age)
print("Department:", Department)
print("Mathematics:", Mathematics)
print("Python:", Python)
print("Statistics:", Statistics)
print("Total score:", Total_score)
print("Average Score:", Average_score)
print("Highest score:", Highest_score)
print("Lowest score:", Lowest_score)

if Pass == True:
    print("Result: Pass")
else:
    print("Result: Fail")
# Out:
# Student Performance Analyzer
# Name: Ojedapo Rodah Opeyemi
# Age: 31
# Department: Art education
# Mathematics: 85
# Python: 87
# Statistics: 92
# Total score: 264
# Average Score: 88.0
# Highest score: 92
# Lowest score: 85
# Result: Pass
